# %% [markdown]
# <a href="https://colab.research.google.com/github/rmontteiro/Data_Science/blob/master/Trab_pratico_mod2_concatena%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from os import listdir
import glob

# %%
#import csv files from folder
path =r'/content/CSVS_EXERCICIO'
allFiles = glob.glob(path + "/*.csv")
stockstats_data = pd.DataFrame()
list_ = []

# %%
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None,sep='|',encoding='latin-1')
    list_.append(df)
    stockstats_data = pd.concat(list_)
    print(file_ + " has been imported.")
# Out:
# /content/CSVS_EXERCICIO/2020-10-08.csv has been imported.
# /content/CSVS_EXERCICIO/2020-06-02.csv has been imported.
# /content/CSVS_EXERCICIO/2020-01-15.csv has been imported.
# /content/CSVS_EXERCICIO/2020-10-24.csv has been imported.
# /content/CSVS_EXERCICIO/2020-08-16.csv has been imported.
# /content/CSVS_EXERCICIO/2020-05-04.csv has been imported.
# /content/CSVS_EXERCICIO/2020-02-28.csv has been imported.
# /content/CSVS_EXERCICIO/2020-05-20.csv has been imported.
# /content/CSVS_EXERCICIO/2020-07-20.csv has been imported.
# /content/CSVS_EXERCICIO/2020-01-03.csv has been imported.
# /content/CSVS_EXERCICIO/2020-05-11.csv has been imported.
# /content/CSVS_EXERCICIO/2020-07-21.csv has been imported.
# /content/CSVS_EXERCICIO/2020-04-27.csv has been imported.
# /content/CSVS_EXERCICIO/2020-06-30.csv has been imported.
# /content/CSVS_EXERCICIO/2020-12-05.csv has been imported.
# /content/CSVS_EXERCICIO/2020-05-03.csv has been imported.
# ...

# %%
stockstats_data.head(20)
# Out:
#    cod_pessoa data_coleta  ... bebida_favorita             hobbies
# 0    10141944  2020-10-08  ...            Água  Aprender algo novo
# 1    10142042  2020-10-08  ...         Cerveja    Praticar esporte
# 2    10142488  2020-10-08  ...         Cerveja         Assistir TV
# 3    10143534  2020-10-08  ...           Vinho      Escutar música
# 4    10143572  2020-10-08  ...         Cerveja         Assistir TV
# 0    10141530  2020-06-02  ...             Chá      Escutar música
# 1    10142589  2020-06-02  ...         Cerveja         Assistir TV
# 2    10142692  2020-06-02  ...         Cerveja      Pintar quadros
# 0    10142171  2020-01-15  ...         Cerveja            Escrever
# 1    10142179  2020-01-15  ...         Cerveja         Assistir TV
# 2    10142530  2020-01-15  ...         Cerveja    Praticar esporte
# 3    10143547  2020-01-15  ...            Água              Dormir
# 4    10143621  2020-01-15  ...            Água      Escutar música
# ...
